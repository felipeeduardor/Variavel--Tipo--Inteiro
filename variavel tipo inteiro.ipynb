# %%
# variavel tipo inteiro
x = 1
print(x)
# cria variavel tipo float
y = 3.13
print(y)
#variavel tipo string
m = 'python'
m = "python"
print(m)
#cria variavel lógica
w = True
y = False
print(y)
# Out:
# 1
# 3.13
# python
# False

# %%
 #calculadora
 x = 10
 y = 20
 z = 100
 w =  (z + y)* y / 100

 print(w)
# Out:
# 24.0

# %%
#exibir texto de console
print('este texto será impresso no console')
print(x)
print("texto é duas variavei : " , x ,", " , z)
# Out:
# este texto será impresso no console
# 10
# texto é duas variavei :  10 ,  100

# %%
#verificar tipo
print(type(x))
print(type(m))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#Entrada de dados
print("informe o valor : ")
i =input()
#mostra tipo string
print(type(i))
# Out:
# informe o valor :
# 4
# <class 'str'>

# %%
#entrada de valor de msgn separada junta
print("informe o valor: ")
i = input()
#ou
i = input("informe o valor : ")
# Out:
# informe o valor:
# 1
# informe o valor : 3

# %%
#conversão de valores para inteiro
var = input("informe o valor : ")
print(type(var))
var = int(var)
print(type(var))
# Out:
# informe o valor : 2
# <class 'str'>
# <class 'int'>

# %%
# para float
var = input("informe o valor: ")
print(type(var))
var =(float(var))
print(type(var))
# Out:
# informe o valor: 3
# <class 'str'>
# <class 'float'>

# %%
# este texto é um comentario
x = 10  # a partir daqui e um comentario
